# %%
import sinter
import pymatching
import numpy as np
from typing import *
import math
import csv
from Surface import surface_data 
from generate_circuit import generate_circuit

# Generate the data
def my_circuit(n, noise, noise2):
    data = surface_data(n, 2 * n, n, 3, display_svg=False)
    circuit = generate_circuit(data, noise, noise2, n)
    return circuit

base = 5000
pr = np.arange(0.001, 0.03, 0.001)
#print(pr)

# Iterate over different n values
n_values = [3, 5, 7]
results = []

for n in n_values:
    CAT_code_tasks = [
        sinter.Task(
            circuit=my_circuit(n, p, noise2= 0.1),
            json_metadata={'p': p},
        )
        for p in pr
    ]

    # Sampling
    collected_baconshor_code_stats: List[sinter.TaskStats] = sinter.collect(
        num_workers=9,
        tasks=CAT_code_tasks,
        decoders=['pymatching'],
        max_shots=base * 1000,
        max_errors=base,
        print_progress=True,
    )

    # Get data (physical error rate=p, logical error rate=l)
    for stats in collected_baconshor_code_stats:
        p = stats.json_metadata['p']
        l = stats.errors / stats.shots if stats.errors != 0 else 0
        results.append([n, p, l])

# Save results to a CSV file
with open('results_new.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['n', 'physical_error_rate', 'logical_error_rate'])
    writer.writerows(results)
# Out:
# Starting 9 workers...
# 20 cases left:
#     pymatching processes=5  ~core_mins_left=0       shots_left=4999400  errors_left=4800    {p=0.010000000000000002}
#     pymatching processes=4  ~core_mins_left=1       shots_left=4998600  errors_left=4452    {p=0.011}
#     pymatching processes=0  ~core_mins_left=0       shots_left=4999900  errors_left=4965    {p=0.012}
#     pymatching processes=0  ~core_mins_left=1       shots_left=4999500  errors_left=4787    {p=0.013000000000000001}
#     pymatching processes=0  ~core_mins_left=0       shots_left=4999900  errors_left=4961    {p=0.014000000000000002}
#     pymatching processes=0  ~core_mins_left=0       shots_left=4999900  errors_left=4949    {p=0.015}
#     pymatching processes=0  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.016}
#     pymatching processes=0  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.017}
#     pymatching processes=0  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.018000000000000002}
# Done collecting
# Starting 9 workers...
# 29 cases left:
#     pymatching processes=4  ~core_mins_left=1       shots_left=4982000  errors_left=3354    {p=0.001}
#     pymatching processes=4  ~core_mins_left=1       shots_left=4994000  errors_left=4309    {p=0.002}
#     pymatching processes=1  ~core_mins_left=1       shots_left=4999700  errors_left=4957    {p=0.003}
#     pymatching processes=0  ~core_mins_left=3       shots_left=4999900  errors_left=4982    {p=0.004}
#     pymatching processes=0  ~core_mins_left=3       shots_left=4999900  errors_left=4986    {p=0.005}
#     pymatching processes=0  ~core_mins_left=2       shots_left=4999900  errors_left=4976    {p=0.006}
#     pymatching processes=0  ~core_mins_left=2       shots_left=4999900  errors_left=4979    {p=0.007}
#     pymatching processes=0  ~core_mins_left=2       shots_left=4999900  errors_left=4965    {p=0.008}
#     pymatching processes=0  ~core_mins_left=1       shots_left=4999900  errors_left=4958    {p=0.009000000000000001}
# 16 cases left:
#     pymatching processes=5  ~core_mins_left=1       shots_left=4996400  errors_left=3403    {p=0.014000000000000002}
#     pymatching processes=3  ~core_mins_left=1       shots_left=4999400  errors_left=4726    {p=0.015}
#     pymatching processes=0  ~core_mins_left=1       shots_left=4999900  errors_left=4947    {p=0.016}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.017}
# 7 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=4992764  errors_left=1404    {p=0.023}
#     pymatching processes=3  ~core_mins_left=1       shots_left=4996922  errors_left=3478    {p=0.024}
#     pymatching processes=4  ~core_mins_left=1       shots_left=4999400  errors_left=4709    {p=0.025}
#     pymatching processes=1  ~core_mins_left=1       shots_left=4999900  errors_left=4947    {p=0.026000000000000002}
# Done collecting
# Starting 9 workers...
# 29 cases left:
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.001}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.002}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.003}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.004}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.005}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.006}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.007}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.008}
#     pymatching processes=1  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.009000000000000001}
# 27 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=4974732  errors_left=1815    {p=0.003}
#     pymatching processes=3  ~core_mins_left=1       shots_left=4989600  errors_left=3334    {p=0.004}
#     pymatching processes=4  ~core_mins_left=1       shots_left=4998900  errors_left=4801    {p=0.005}
#     pymatching processes=0  ~core_mins_left=3       shots_left=4999900  errors_left=4979    {p=0.006}
#     pymatching processes=0  ~core_mins_left=2       shots_left=4999900  errors_left=4973    {p=0.007}
#     pymatching processes=0  ~core_mins_left=2       shots_left=4999900  errors_left=4963    {p=0.008}
#     pymatching processes=0  ~core_mins_left=2       shots_left=4999900  errors_left=4965    {p=0.009000000000000001}
# 22 cases left:
#     pymatching processes=4  ~core_mins_left=1       shots_left=4992700  errors_left=2651    {p=0.008}
#     pymatching processes=3  ~core_mins_left=1       shots_left=4997600  errors_left=4106    {p=0.009000000000000001}
#     pymatching processes=1  ~core_mins_left=1       shots_left=4999900  errors_left=4959    {p=0.010000000000000002}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.011}
# 18 cases left:
#     pymatching processes=5  ~core_mins_left=1       shots_left=4998600  errors_left=4370    {p=0.012}
#     pymatching processes=3  ~core_mins_left=1       shots_left=4999200  errors_left=4640    {p=0.013000000000000001}
#     pymatching processes=1  ~core_mins_left=1       shots_left=4999900  errors_left=4950    {p=0.014000000000000002}
#     pymatching processes=0  ~core_mins_left=1       shots_left=4999900  errors_left=4947    {p=0.015}
# 15 cases left:
#     pymatching processes=3  ~core_mins_left=1       shots_left=4996943  errors_left=3513    {p=0.015}
#     pymatching processes=4  ~core_mins_left=1       shots_left=4998800  errors_left=4415    {p=0.016}
#     pymatching processes=2  ~core_mins_left=1       shots_left=4999700  errors_left=4844    {p=0.017}
#     pymatching processes=0  ~core_mins_left=1       shots_left=4999900  errors_left=4946    {p=0.018000000000000002}
# 12 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=4992640  errors_left=1315    {p=0.018000000000000002}
#     pymatching processes=5  ~core_mins_left=1       shots_left=4998800  errors_left=4433    {p=0.019000000000000003}
#     pymatching processes=2  ~core_mins_left=1       shots_left=4999600  errors_left=4805    {p=0.02}
#     pymatching processes=1  ~core_mins_left=1       shots_left=4999900  errors_left=4951    {p=0.021}
# 9 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=4993091  errors_left=1496    {p=0.021}
#     pymatching processes=4  ~core_mins_left=1       shots_left=4999000  errors_left=4488    {p=0.022000000000000002}
#     pymatching processes=4  ~core_mins_left=1       shots_left=4999400  errors_left=4707    {p=0.023}
#     pymatching processes=0  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.024}
#     pymatching processes=0  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.025}
# 6 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=4995689  errors_left=2851    {p=0.024}
#     pymatching processes=4  ~core_mins_left=1       shots_left=4998200  errors_left=4132    {p=0.025}
#     pymatching processes=3  ~core_mins_left=1       shots_left=4999700  errors_left=4863    {p=0.026000000000000002}
#     pymatching processes=0  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.027000000000000003}
#     pymatching processes=0  ~core_mins_left=None    shots_left=5000000  errors_left=5000    {p=0.028}
# 4 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=4990057  errors_left=18      {p=0.026000000000000002}
#     pymatching processes=2  ~core_mins_left=1       shots_left=4995254  errors_left=2692    {p=0.027000000000000003}
#     pymatching processes=3  ~core_mins_left=1       shots_left=4997800  errors_left=3931    {p=0.028}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.029}
# 1 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=4994670  errors_left=2358    {p=0.029}
# Done collecting

# %%
import matplotlib.pyplot as plt
import csv

def load_results_from_csv(filepath: str):
    results = []
    with open(filepath, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            n = int(row['n'])
            p = float(row['physical_error_rate'])
            l = float(row['logical_error_rate'])
            results.append([n, p, l])
    return results


import matplotlib.pyplot as plt
from collections import defaultdict

def plot_results(results):
    # Organize results into a dictionary
    data = defaultdict(lambda: {'plist': [], 'llist': []})
    
    for result in results:
        n, p, l = result
        data[n]['plist'].append(p)
        data[n]['llist'].append(l)

    plt.figure(figsize=(20, 10))

    # Generate colors dynamically if needed
    colors = ['blue', 'green', 'orange']
    n_values = list(data.keys())

    if len(colors) < len(n_values):
        import itertools
        colors = list(itertools.cycle(colors))

    # Generate labels dynamically
    labels = [f'CAT State Surface{n}' for n in n_values]

    for idx, n in enumerate(n_values):
        plist = data[n]['plist']
        llist = data[n]['llist']

        if len(plist) == 0 or len(llist) == 0:
            print(f'Warning: No data for n = {n}')
            continue

        # Combine plist and llist, sort by plist, and unzip
        sorted_data = sorted(zip(plist, llist))
        sorted_plist, sorted_llist = zip(*sorted_data)

        # Print data points to verify
        #print(f'n = {n}')
        #for p, l in zip(sorted_plist, sorted_llist):
            #print(f'Physical Error Rate: {p}, Logical Error Rate: {l}')

        # Plot data points and lines
        plt.loglog(sorted_plist, sorted_llist, marker='o', linestyle='-', linewidth=2, color=colors[idx], label=labels[idx])

    # Add labels to plot
    plt.xscale('log')
    plt.yscale('log')
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.xlabel("Physical Error Rate", fontsize=25)
    plt.ylabel("Logical Error Rate", fontsize=25)
    legend = plt.legend(title='', fontsize=20)
    plt.savefig('CAT_inverted.pdf')
    plt.show()


plot_results(results)

# Or load from CSV and plot
#data_from_csv = load_results_from_csv('results.csv')
#plot_results(data_from_csv)
