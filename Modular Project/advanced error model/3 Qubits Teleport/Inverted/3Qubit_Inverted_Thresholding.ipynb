# %%
import sinter
import pymatching
import numpy as np
from typing import *
import math
import csv
from Surface import surface_data 
from generate_circuit import generate_circuit

# Generate the data
def my_circuit(n, noise, noise2):
    data = surface_data(n, 2 * n, n, 3, display_svg=False)
    circuit = generate_circuit(data, noise, noise2, n)
    return circuit

base = 1000
pr = np.arange(0.001, 0.03, 0.001)
#print(pr)

# Iterate over different n values
n_values = [3, 5, 7]
results = []

for n in n_values:
    Q3ubit_code_tasks = [
        sinter.Task(
            circuit=my_circuit(n, p, noise2=0.05),
            json_metadata={'p': p},
        )
        for p in pr
    ]

    # Sampling
    collected_baconshor_code_stats: List[sinter.TaskStats] = sinter.collect(
        num_workers=9,
        tasks=Q3ubit_code_tasks,
        decoders=['pymatching'],
        max_shots=base * 1000,
        max_errors=base,
        print_progress=True,
    )

    # Get data (physical error rate=p, logical error rate=l)
    for stats in collected_baconshor_code_stats:
        p = stats.json_metadata['p']
        l = stats.errors / stats.shots if stats.errors != 0 else 0
        results.append([n, p, l])

# Save results to a CSV file
with open('results.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['n', 'physical_error_rate', 'logical_error_rate'])
    writer.writerows(results)
# Out:
# Starting 9 workers...
# 10 cases left:
#     pymatching processes=4  ~core_mins_left=1       shots_left=999316   errors_left=705     {p=0.02}
#     pymatching processes=1  ~core_mins_left=0       shots_left=998200   errors_left=190     {p=0.021}
#     pymatching processes=3  ~core_mins_left=0       shots_left=999900   errors_left=954     {p=0.022000000000000002}
#     pymatching processes=1  ~core_mins_left=0       shots_left=999900   errors_left=957     {p=0.023}
#     pymatching processes=0  ~core_mins_left=0       shots_left=999900   errors_left=943     {p=0.024}
#     pymatching processes=0  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.025}
#     pymatching processes=0  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.026000000000000002}
#     pymatching processes=0  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.027000000000000003}
# Done collecting
# Starting 9 workers...
# 28 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=991773   errors_left=5       {p=0.002}
#     pymatching processes=4  ~core_mins_left=1       shots_left=998200   errors_left=757     {p=0.003}
#     pymatching processes=3  ~core_mins_left=1       shots_left=999100   errors_left=849     {p=0.004}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=982     {p=0.005}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=973     {p=0.006}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=977     {p=0.007}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=968     {p=0.008}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=965     {p=0.009000000000000001}
# 4 cases left:
#     pymatching processes=3  ~core_mins_left=1       shots_left=999400   errors_left=711     {p=0.026000000000000002}
#     pymatching processes=4  ~core_mins_left=1       shots_left=999400   errors_left=681     {p=0.027000000000000003}
#     pymatching processes=2  ~core_mins_left=1       shots_left=999900   errors_left=946     {p=0.028}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=949     {p=0.029}
# Done collecting
# Starting 9 workers...
# 29 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=999900   errors_left=989     {p=0.001}
#     pymatching processes=1  ~core_mins_left=1       shots_left=999900   errors_left=988     {p=0.002}
#     pymatching processes=1  ~core_mins_left=1       shots_left=999900   errors_left=990     {p=0.003}
#     pymatching processes=1  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.004}
#     pymatching processes=1  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.005}
#     pymatching processes=1  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.006}
#     pymatching processes=1  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.007}
#     pymatching processes=1  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.008}
#     pymatching processes=1  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.009000000000000001}
# 22 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=998046   errors_left=313     {p=0.008}
#     pymatching processes=3  ~core_mins_left=1       shots_left=999400   errors_left=758     {p=0.009000000000000001}
#     pymatching processes=1  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.010000000000000002}
#     pymatching processes=1  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.011}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.012}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.013000000000000001}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.014000000000000002}
# 14 cases left:
#     pymatching processes=3  ~core_mins_left=1       shots_left=999900   errors_left=947     {p=0.016}
#     pymatching processes=3  ~core_mins_left=1       shots_left=999900   errors_left=944     {p=0.017}
#     pymatching processes=2  ~core_mins_left=1       shots_left=999900   errors_left=950     {p=0.018000000000000002}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=943     {p=0.019000000000000003}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=955     {p=0.02}
#     pymatching processes=0  ~core_mins_left=1       shots_left=999900   errors_left=952     {p=0.021}
#     pymatching processes=0  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.022000000000000002}
#     pymatching processes=0  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.023}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.024}
# 6 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=998053   errors_left=29      {p=0.024}
#     pymatching processes=3  ~core_mins_left=1       shots_left=999900   errors_left=948     {p=0.025}
#     pymatching processes=3  ~core_mins_left=1       shots_left=999900   errors_left=960     {p=0.026000000000000002}
#     pymatching processes=0  ~core_mins_left=None    shots_left=1000000  errors_left=1000    {p=0.027000000000000003}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.028}
# Done collecting

# %%
import matplotlib.pyplot as plt
import csv

def load_results_from_csv(filepath: str):
    results = []
    with open(filepath, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            n = int(row['n'])
            p = float(row['physical_error_rate'])
            l = float(row['logical_error_rate'])
            results.append([n, p, l])
    return results


import matplotlib.pyplot as plt
from collections import defaultdict

def plot_results(results):
    # Organize results into a dictionary
    data = defaultdict(lambda: {'plist': [], 'llist': []})
    
    for result in results:
        n, p, l = result
        data[n]['plist'].append(p)
        data[n]['llist'].append(l)

    plt.figure(figsize=(20, 10))

    # Generate colors dynamically if needed
    colors = ['blue', 'green', 'orange', 'black']
    n_values = list(data.keys())

    if len(colors) < len(n_values):
        import itertools
        colors = list(itertools.cycle(colors))

    # Generate labels dynamically
    labels = [f'3Qubit Teleport  Surface{n}' for n in n_values]

    for idx, n in enumerate(n_values):
        plist = data[n]['plist']
        llist = data[n]['llist']

        if len(plist) == 0 or len(llist) == 0:
            print(f'Warning: No data for n = {n}')
            continue

        # Combine plist and llist, sort by plist, and unzip
        sorted_data = sorted(zip(plist, llist))
        sorted_plist, sorted_llist = zip(*sorted_data)

        # Print data points to verify
        #print(f'n = {n}')
        #for p, l in zip(sorted_plist, sorted_llist):
            #print(f'Physical Error Rate: {p}, Logical Error Rate: {l}')

        # Plot data points and lines
        plt.loglog(sorted_plist, sorted_llist, marker='o', linestyle='-', linewidth=2, color=colors[idx], label=labels[idx])

    # Add labels to plot
    plt.xscale('log')
    plt.yscale('log')
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.xlabel("Physical Error Rate", fontsize=25)
    plt.ylabel("Logical Error Rate", fontsize=25)
    legend = plt.legend(title='', fontsize=20)
    plt.savefig('3Qubit_inverted_new.pdf')
    plt.show()

plot_results(results)
# Or load from CSV and plot
#data_from_csv = load_results_from_csv('results.csv')
#plot_results(data_from_csv)
