# %%
import sinter
import pymatching
import numpy as np
from typing import *
import math
import csv
from Surface import surface_data 
from generate_circuit import generate_circuit

# Generate the data
def my_circuit(n, noise, noise2):
    data = surface_data(n, 2 * n, n, 3, display_svg=False)
    circuit = generate_circuit(data, noise, noise2, n)
    return circuit

base = 500
pr = np.arange(0.001, 0.03, 0.001)
#print(pr)

# Iterate over different n values
n_values = [3, 5, 7]
results = []

for n in n_values:
    Q3ubit_code_tasks = [
        sinter.Task(
            circuit=my_circuit(n, p, noise2=0.1),
            json_metadata={'p': p},
        )
        for p in pr
    ]

    # Sampling
    collected_baconshor_code_stats: List[sinter.TaskStats] = sinter.collect(
        num_workers=9,
        tasks=Q3ubit_code_tasks,
        decoders=['pymatching'],
        max_shots=base * 100,
        max_errors=base,
        print_progress=True,
    )

    # Get data (physical error rate=p, logical error rate=l)
    for stats in collected_baconshor_code_stats:
        p = stats.json_metadata['p']
        l = stats.errors / stats.shots if stats.errors != 0 else 0
        results.append([n, p, l])

# Save results to a CSV file
with open('results.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['n', 'physical_error_rate', 'logical_error_rate'])
    writer.writerows(results)
# Out:
# Starting 9 workers...
# 29 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=14400    errors_left=493     {p=0.001}
#     pymatching processes=1  ~core_mins_left=1       shots_left=15600    errors_left=468     {p=0.002}
#     pymatching processes=4  ~core_mins_left=1       shots_left=39200    errors_left=459     {p=0.003}
#     pymatching processes=3  ~core_mins_left=1       shots_left=41000    errors_left=463     {p=0.004}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49700    errors_left=498     {p=0.005}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=499     {p=0.006}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=500     {p=0.007}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49900    errors_left=498     {p=0.008}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=499     {p=0.009000000000000001}
# Done collecting
# Starting 9 workers...
# 29 cases left:
#     pymatching processes=5  ~core_mins_left=1       shots_left=46400    errors_left=500     {p=0.001}
#     pymatching processes=4  ~core_mins_left=1       shots_left=48000    errors_left=500     {p=0.002}
#     pymatching processes=0  ~core_mins_left=1       shots_left=49500    errors_left=500     {p=0.003}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=500     {p=0.004}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=500     {p=0.005}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49900    errors_left=498     {p=0.006}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=499     {p=0.007}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=499     {p=0.008}
#     pymatching processes=0  ~core_mins_left=1       shots_left=49900    errors_left=496     {p=0.009000000000000001}
# 27 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=28000    errors_left=492     {p=0.003}
#     pymatching processes=2  ~core_mins_left=1       shots_left=24800    errors_left=470     {p=0.004}
#     pymatching processes=4  ~core_mins_left=1       shots_left=46700    errors_left=489     {p=0.005}
#     pymatching processes=1  ~core_mins_left=2       shots_left=49900    errors_left=498     {p=0.006}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=499     {p=0.007}
#     pymatching processes=0  ~core_mins_left=4       shots_left=49900    errors_left=499     {p=0.008}
#     pymatching processes=0  ~core_mins_left=1       shots_left=49900    errors_left=496     {p=0.009000000000000001}
# 24 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=32400    errors_left=394     {p=0.006}
#     pymatching processes=3  ~core_mins_left=1       shots_left=29200    errors_left=297     {p=0.007}
#     pymatching processes=4  ~core_mins_left=1       shots_left=45700    errors_left=428     {p=0.008}
#     pymatching processes=0  ~core_mins_left=1       shots_left=49900    errors_left=496     {p=0.009000000000000001}
# 19 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=43365    errors_left=162     {p=0.011}
#     pymatching processes=3  ~core_mins_left=1       shots_left=46400    errors_left=251     {p=0.012}
#     pymatching processes=3  ~core_mins_left=1       shots_left=49900    errors_left=494     {p=0.013000000000000001}
#     pymatching processes=0  ~core_mins_left=1       shots_left=49900    errors_left=485     {p=0.014000000000000002}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.015}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.016}
# 3 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=48553    errors_left=3       {p=0.026000000000000002}
#     pymatching processes=1  ~core_mins_left=1       shots_left=49302    errors_left=214     {p=0.028}
#     pymatching processes=2  ~core_mins_left=1       shots_left=49400    errors_left=236     {p=0.029}
# Done collecting
# Starting 9 workers...
# 29 cases left:
#     pymatching processes=2  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.001}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.002}
#     pymatching processes=1  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.003}
#     pymatching processes=1  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.004}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.005}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.006}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.007}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.008}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.009000000000000001}
# 29 cases left:
#     pymatching processes=3  ~core_mins_left=1       shots_left=31600    errors_left=500     {p=0.001}
#     pymatching processes=4  ~core_mins_left=1       shots_left=40800    errors_left=500     {p=0.002}
#     pymatching processes=2  ~core_mins_left=1       shots_left=48900    errors_left=498     {p=0.003}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49700    errors_left=500     {p=0.004}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.005}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=499     {p=0.006}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.007}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49900    errors_left=496     {p=0.008}
#     pymatching processes=0  ~core_mins_left=3       shots_left=49900    errors_left=498     {p=0.009000000000000001}
# 29 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=24400    errors_left=500     {p=0.001}
#     pymatching processes=2  ~core_mins_left=1       shots_left=28800    errors_left=500     {p=0.002}
#     pymatching processes=4  ~core_mins_left=1       shots_left=43400    errors_left=498     {p=0.003}
#     pymatching processes=1  ~core_mins_left=1       shots_left=47300    errors_left=499     {p=0.004}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.005}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=499     {p=0.006}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.007}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49900    errors_left=496     {p=0.008}
#     pymatching processes=0  ~core_mins_left=3       shots_left=49900    errors_left=498     {p=0.009000000000000001}
# 28 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=17600    errors_left=500     {p=0.002}
#     pymatching processes=2  ~core_mins_left=1       shots_left=23600    errors_left=498     {p=0.003}
#     pymatching processes=3  ~core_mins_left=1       shots_left=33800    errors_left=494     {p=0.004}
#     pymatching processes=3  ~core_mins_left=1       shots_left=44400    errors_left=493     {p=0.005}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=499     {p=0.006}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.007}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49900    errors_left=496     {p=0.008}
#     pymatching processes=0  ~core_mins_left=3       shots_left=49900    errors_left=498     {p=0.009000000000000001}
# 26 cases left:
#     pymatching processes=2  ~core_mins_left=1       shots_left=28400    errors_left=493     {p=0.004}
#     pymatching processes=3  ~core_mins_left=1       shots_left=34000    errors_left=477     {p=0.005}
#     pymatching processes=4  ~core_mins_left=1       shots_left=44600    errors_left=482     {p=0.006}
#     pymatching processes=0  ~core_mins_left=5       shots_left=49900    errors_left=500     {p=0.007}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49900    errors_left=496     {p=0.008}
#     pymatching processes=0  ~core_mins_left=3       shots_left=49900    errors_left=498     {p=0.009000000000000001}
# 26 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=17600    errors_left=490     {p=0.004}
#     pymatching processes=1  ~core_mins_left=1       shots_left=16400    errors_left=459     {p=0.005}
#     pymatching processes=4  ~core_mins_left=1       shots_left=37400    errors_left=444     {p=0.006}
#     pymatching processes=3  ~core_mins_left=1       shots_left=45700    errors_left=460     {p=0.007}
#     pymatching processes=0  ~core_mins_left=2       shots_left=49900    errors_left=496     {p=0.008}
#     pymatching processes=0  ~core_mins_left=3       shots_left=49900    errors_left=498     {p=0.009000000000000001}
# 24 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=10800    errors_left=354     {p=0.006}
#     pymatching processes=4  ~core_mins_left=1       shots_left=37400    errors_left=390     {p=0.007}
#     pymatching processes=4  ~core_mins_left=1       shots_left=48500    errors_left=466     {p=0.008}
#     pymatching processes=0  ~core_mins_left=3       shots_left=49900    errors_left=498     {p=0.009000000000000001}
# 23 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=17000    errors_left=221     {p=0.007}
#     pymatching processes=4  ~core_mins_left=1       shots_left=39080    errors_left=326     {p=0.008}
#     pymatching processes=4  ~core_mins_left=1       shots_left=46400    errors_left=413     {p=0.009000000000000001}
# 23 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=17000    errors_left=221     {p=0.007}
#     pymatching processes=1  ~core_mins_left=1       shots_left=26792    errors_left=108     {p=0.008}
#     pymatching processes=1  ~core_mins_left=1       shots_left=37679    errors_left=154     {p=0.009000000000000001}
#     pymatching processes=5  ~core_mins_left=1       shots_left=46400    errors_left=313     {p=0.010000000000000002}
#     pymatching processes=1  ~core_mins_left=1       shots_left=49700    errors_left=483     {p=0.011}
#     pymatching processes=0  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.012}
# 18 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=46400    errors_left=167     {p=0.012}
#     pymatching processes=4  ~core_mins_left=1       shots_left=48800    errors_left=354     {p=0.013000000000000001}
#     pymatching processes=3  ~core_mins_left=1       shots_left=49900    errors_left=480     {p=0.014000000000000002}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.015}
# 13 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=48043    errors_left=1       {p=0.017}
#     pymatching processes=3  ~core_mins_left=1       shots_left=49900    errors_left=469     {p=0.018000000000000002}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.019000000000000003}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.02}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.021}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.022000000000000002}
#     pymatching processes=0  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.023}
#     pymatching processes=0  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.024}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.025}
# 7 cases left:
#     pymatching processes=1  ~core_mins_left=1       shots_left=48800    errors_left=7       {p=0.023}
#     pymatching processes=1  ~core_mins_left=1       shots_left=48958    errors_left=19      {p=0.024}
#     pymatching processes=1  ~core_mins_left=1       shots_left=49282    errors_left=199     {p=0.025}
#     pymatching processes=3  ~core_mins_left=1       shots_left=49900    errors_left=443     {p=0.026000000000000002}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.027000000000000003}
#     pymatching processes=1  ~core_mins_left=None    shots_left=50000    errors_left=500     {p=0.028}
#     pymatching processes=1  ~core_mins_left=None    (initializing...) {p=0.029}
# Done collecting

# %%
import matplotlib.pyplot as plt
import csv

def load_results_from_csv(filepath: str):
    results = []
    with open(filepath, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            n = int(row['n'])
            p = float(row['physical_error_rate'])
            l = float(row['logical_error_rate'])
            results.append([n, p, l])
    return results


import matplotlib.pyplot as plt
from collections import defaultdict

def plot_results(results):
    # Organize results into a dictionary
    data = defaultdict(lambda: {'plist': [], 'llist': []})
    
    for result in results:
        n, p, l = result
        data[n]['plist'].append(p)
        data[n]['llist'].append(l)

    plt.figure(figsize=(20, 10))

    # Generate colors dynamically if needed
    colors = ['blue', 'green', 'orange']
    n_values = list(data.keys())

    if len(colors) < len(n_values):
        import itertools
        colors = list(itertools.cycle(colors))

    # Generate labels dynamically
    labels = [f'3Qubit Teleport  Surface{n}' for n in n_values]

    for idx, n in enumerate(n_values):
        plist = data[n]['plist']
        llist = data[n]['llist']

        if len(plist) == 0 or len(llist) == 0:
            print(f'Warning: No data for n = {n}')
            continue

        # Combine plist and llist, sort by plist, and unzip
        sorted_data = sorted(zip(plist, llist))
        sorted_plist, sorted_llist = zip(*sorted_data)

        # Print data points to verify
        #print(f'n = {n}')
        #for p, l in zip(sorted_plist, sorted_llist):
            #print(f'Physical Error Rate: {p}, Logical Error Rate: {l}')

        # Plot data points and lines
        plt.loglog(sorted_plist, sorted_llist, marker='o', linestyle='-', linewidth=2, color=colors[idx], label=labels[idx])

    # Add labels to plot
    plt.xscale('log')
    plt.yscale('log')
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.xlabel("Physical Error Rate", fontsize=25)
    plt.ylabel("Logical Error Rate", fontsize=25)
    legend = plt.legend(title='', fontsize=20)
    plt.savefig('3Qubit_regular.pdf')
    plt.show()

#plot_results(results)
# Or load from CSV and plot
data_from_csv = load_results_from_csv('results.csv')
plot_results(data_from_csv)
